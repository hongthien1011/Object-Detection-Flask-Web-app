# %%
import os
from PIL import Image

yourpath = os.getcwd()
for root, dirs, files in os.walk(yourpath, topdown=False):
    for name in files:
        print(os.path.join(root, name))
        if os.path.splitext(os.path.join(root, name))[1].lower() == ".tiff":
            if os.path.isfile(os.path.splitext(os.path.join(root, name))[0] + ".jpg"):
                print("A jpeg file already exists for %s" % name)
            # If a jpeg is *NOT* present, create one from the tiff.
            else:
                outfile = os.path.splitext(os.path.join(root, name))[0] + ".jpg"
                try:
                    im = Image.open(os.path.join(root, name))
                    print("Generating jpeg for %s" % name)
                    im.thumbnail(im.size)
                    im.save(outfile, "JPEG", quality=100)
                except(Exception, e):
                    print(e)
# Out:
# D:\FloorPlan Data\tường đen mới\.ipynb_checkpoints\Untitled-checkpoint.ipynb
# D:\FloorPlan Data\tường đen mới\file_0.svg
# D:\FloorPlan Data\tường đen mới\file_0.tiff
# Generating jpeg for file_0.tiff
# D:\FloorPlan Data\tường đen mới\file_1.svg
# D:\FloorPlan Data\tường đen mới\file_1.tiff
# Generating jpeg for file_1.tiff
# D:\FloorPlan Data\tường đen mới\file_10.svg
# D:\FloorPlan Data\tường đen mới\file_10.tiff
# Generating jpeg for file_10.tiff
# D:\FloorPlan Data\tường đen mới\file_11.svg
# D:\FloorPlan Data\tường đen mới\file_11.tiff
# Generating jpeg for file_11.tiff
# D:\FloorPlan Data\tường đen mới\file_12.svg
# D:\FloorPlan Data\tường đen mới\file_12.tiff
# Generating jpeg for file_12.tiff
# D:\FloorPlan Data\tường đen mới\file_13.svg
# D:\FloorPlan Data\tường đen mới\file_13.tiff
# Generating jpeg for file_13.tiff
# D:\FloorPlan Data\tường đen mới\file_14.svg
# D:\FloorPlan Data\tường đen mới\file_14.tiff
# Generating jpeg for file_14.tiff
# D:\FloorPlan Data\tường đen mới\file_15.svg
# D:\FloorPlan Data\tường đen mới\file_15.tiff
# Generating jpeg for file_15.tiff
# D:\FloorPlan Data\tường đen mới\file_16.svg
# D:\FloorPlan Data\tường đen mới\file_16.tiff
# Generating jpeg for file_16.tiff
# D:\FloorPlan Data\tường đen mới\file_17.svg
# D:\FloorPlan Data\tường đen mới\file_17.tiff
# Generating jpeg for file_17.tiff
# D:\FloorPlan Data\tường đen mới\file_18.svg
# D:\FloorPlan Data\tường đen mới\file_18.tiff
# Generating jpeg for file_18.tiff
# D:\FloorPlan Data\tường đen mới\file_19.svg
# D:\FloorPlan Data\tường đen mới\file_19.tiff
# Generating jpeg for file_19.tiff
# D:\FloorPlan Data\tường đen mới\file_2.svg
# D:\FloorPlan Data\tường đen mới\file_2.tiff
# Generating jpeg for file_2.tiff
# D:\FloorPlan Data\tường đen mới\file_20.svg
# D:\FloorPlan Data\tường đen mới\file_20.tiff
# Generating jpeg for file_20.tiff
# D:\FloorPlan Data\tường đen mới\file_21.svg
# D:\FloorPlan Data\tường đen mới\file_21.tiff
# Generating jpeg for file_21.tiff
# D:\FloorPlan Data\tường đen mới\file_22.svg
# D:\FloorPlan Data\tường đen mới\file_22.tiff
# Generating jpeg for file_22.tiff
# D:\FloorPlan Data\tường đen mới\file_23.svg
# D:\FloorPlan Data\tường đen mới\file_23.tiff
# Generating jpeg for file_23.tiff
# D:\FloorPlan Data\tường đen mới\file_24.svg
# D:\FloorPlan Data\tường đen mới\file_24.tiff
# Generating jpeg for file_24.tiff
# D:\FloorPlan Data\tường đen mới\file_25.svg
# D:\FloorPlan Data\tường đen mới\file_25.tiff
# Generating jpeg for file_25.tiff
# D:\FloorPlan Data\tường đen mới\file_26.svg
# D:\FloorPlan Data\tường đen mới\file_26.tiff
# Generating jpeg for file_26.tiff
# D:\FloorPlan Data\tường đen mới\file_27.svg
# D:\FloorPlan Data\tường đen mới\file_27.tiff
# Generating jpeg for file_27.tiff
# D:\FloorPlan Data\tường đen mới\file_28.svg
# D:\FloorPlan Data\tường đen mới\file_28.tiff
# Generating jpeg for file_28.tiff
# D:\FloorPlan Data\tường đen mới\file_29.svg
# D:\FloorPlan Data\tường đen mới\file_29.tiff
# Generating jpeg for file_29.tiff
# D:\FloorPlan Data\tường đen mới\file_3.svg
# D:\FloorPlan Data\tường đen mới\file_3.tiff
# Generating jpeg for file_3.tiff
# D:\FloorPlan Data\tường đen mới\file_30.svg
# D:\FloorPlan Data\tường đen mới\file_30.tiff
# Generating jpeg for file_30.tiff
# D:\FloorPlan Data\tường đen mới\file_31.svg
# D:\FloorPlan Data\tường đen mới\file_31.tiff
# Generating jpeg for file_31.tiff
# D:\FloorPlan Data\tường đen mới\file_32.svg
# D:\FloorPlan Data\tường đen mới\file_32.tiff
# Generating jpeg for file_32.tiff
# D:\FloorPlan Data\tường đen mới\file_33.svg
# D:\FloorPlan Data\tường đen mới\file_33.tiff
# Generating jpeg for file_33.tiff
# D:\FloorPlan Data\tường đen mới\file_34.svg
# D:\FloorPlan Data\tường đen mới\file_34.tiff
# Generating jpeg for file_34.tiff
# D:\FloorPlan Data\tường đen mới\file_35.svg
# D:\FloorPlan Data\tường đen mới\file_35.tiff
# Generating jpeg for file_35.tiff
# D:\FloorPlan Data\tường đen mới\file_36.svg
# D:\FloorPlan Data\tường đen mới\file_36.tiff
# Generating jpeg for file_36.tiff
# D:\FloorPlan Data\tường đen mới\file_37.svg
# D:\FloorPlan Data\tường đen mới\file_37.tiff
# Generating jpeg for file_37.tiff
# D:\FloorPlan Data\tường đen mới\file_38.svg
# D:\FloorPlan Data\tường đen mới\file_38.tiff
# Generating jpeg for file_38.tiff
# D:\FloorPlan Data\tường đen mới\file_39.svg
# D:\FloorPlan Data\tường đen mới\file_39.tiff
# Generating jpeg for file_39.tiff
# D:\FloorPlan Data\tường đen mới\file_4.svg
# D:\FloorPlan Data\tường đen mới\file_4.tiff
# Generating jpeg for file_4.tiff
# D:\FloorPlan Data\tường đen mới\file_40.svg
# D:\FloorPlan Data\tường đen mới\file_40.tiff
# Generating jpeg for file_40.tiff
# D:\FloorPlan Data\tường đen mới\file_41.svg
# D:\FloorPlan Data\tường đen mới\file_41.tiff
# Generating jpeg for file_41.tiff
# D:\FloorPlan Data\tường đen mới\file_42.svg
# D:\FloorPlan Data\tường đen mới\file_42.tiff
# Generating jpeg for file_42.tiff
# D:\FloorPlan Data\tường đen mới\file_43.svg
# D:\FloorPlan Data\tường đen mới\file_43.tiff
# Generating jpeg for file_43.tiff
# D:\FloorPlan Data\tường đen mới\file_44.svg
# D:\FloorPlan Data\tường đen mới\file_44.tiff
# Generating jpeg for file_44.tiff
# D:\FloorPlan Data\tường đen mới\file_5.svg
# D:\FloorPlan Data\tường đen mới\file_5.tiff
# Generating jpeg for file_5.tiff
# D:\FloorPlan Data\tường đen mới\file_6.svg
# D:\FloorPlan Data\tường đen mới\file_6.tiff
# Generating jpeg for file_6.tiff
# D:\FloorPlan Data\tường đen mới\file_7.svg
# D:\FloorPlan Data\tường đen mới\file_7.tiff
# Generating jpeg for file_7.tiff
# D:\FloorPlan Data\tường đen mới\file_8.svg
# D:\FloorPlan Data\tường đen mới\file_8.tiff
# Generating jpeg for file_8.tiff
# D:\FloorPlan Data\tường đen mới\file_9.svg
# D:\FloorPlan Data\tường đen mới\file_9.tiff
# Generating jpeg for file_9.tiff
# D:\FloorPlan Data\tường đen mới\Untitled.ipynb
