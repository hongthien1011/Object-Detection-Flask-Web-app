# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 49.7M/49.7M [01:18<00:00, 665kB/s]

# %%
model.train(data="D:\Phase2\Phase2Data-DoorWindow2Door.v5i.yolov8\data.yaml", epochs=100, batch=-1)
# Out:
# New https://pypi.org/project/ultralytics/8.0.146 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.141  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %%
model = YOLO(r'D:\runs\detect\zolov3_train\weights\best.pt')
model.export(format='onnx', dynamic=True)
# Out:
# Ultralytics YOLOv8.0.141  Python-3.9.17 torch-2.0.1 CPU (12th Gen Intel Core(TM) i7-12700)
# Model summary (fused): 218 layers, 25844392 parameters, 0 gradients
#
# PyTorch: starting from 'D:\runs\detect\zolov3_train\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 12, 8400) (49.6 MB)
#
# ONNX: starting export with onnx 1.14.0 opset 17...
# ================ Diagnostic Run torch.onnx.export version 2.0.1 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# ONNX: export success  2.5s, saved as 'D:\runs\detect\zolov3_train\weights\best.onnx' (98.7 MB)
#
# Export complete (4.9s)
# Results saved to D:\runs\detect\zolov3_train\weights
# Predict:         yolo predict task=detect model=D:\runs\detect\zolov3_train\weights\best.onnx imgsz=640
# ...
