# %%
from ultralytics import YOLO

# %%
model = YOLO(r"D:\runs\detect\zolov3_train\weights\best.pt")

# %%
# !yolo task=detect mode=val split=test model=D:\runs\detect\zolov4_train\weights\best.pt data=D:\Phase2\Phase2Data-DoorWindow2Door.v5i.yolov8\data.yaml

# %%
import os
import random
path = r'D:\Phase2\TestData'
# arr = os.listdir(path)

# numOfTestImg = len(arr)

# testList = range(0, numOfTestImg)

# randomlist = random.sample(testList, 25)

# test_list = []

# # random test
# for i in randomlist:
#     img = arr[i]
#     test_list.append(r'{}\{}'.format(path,img))
# results = model(test_list, save=True,show_labels=True)

model.predict(path, save=True, conf=0.25, show=False,show_labels=True)
# #test all
# for i in testList:
#     img = arr[i]
#     test_list.append(r'{}\{}'.format(path,img))
# results = model(test_list, save=True,show_labels=True)
# Out:
# image 1/42 D:\Phase2\TestData\209d6f3896b1a9f4ff1c6fd53cd9e788.jpg: 640x544 1 2door, 4 doors, 9 window2s, 78.1ms
# image 2/42 D:\Phase2\TestData\2D-Floor-Plan-Images-Samples.jpg: 480x640 7 doors, 4 window2s, 79.5ms
# image 3/42 D:\Phase2\TestData\2D_Basic_Floor_Plan-1024x695.jpg: 448x640 2 doors, 3 window2s, 71.3ms
# image 4/42 D:\Phase2\TestData\2d-plattegrond-begane-grond.jpg: 640x640 5 doors, 11 window2s, 19.6ms
# image 5/42 D:\Phase2\TestData\3.png: 640x576 15 doors, 15 window1s, 94.7ms
# image 6/42 D:\Phase2\TestData\345171052.png: 608x640 2 2doors, 10 doors, 3 window1s, 5 window2s, 66.3ms
# image 7/42 D:\Phase2\TestData\4605071b-3b7a-4891-bdc5-43975736c2ab.png: 544x640 1 2door, 6 doors, 4 window2s, 71.8ms
# image 8/42 D:\Phase2\TestData\7-4.png: 640x512 5 doors, 7 window2s, 68.8ms
# image 9/42 D:\Phase2\TestData\7.png: 640x640 11 doors, 7 window1s, 1 window2, 18.0ms
# image 10/42 D:\Phase2\TestData\7e0e630383dce33a94cfc604dbb3026a.jpg: 512x640 4 window2s, 70.4ms
# ...
