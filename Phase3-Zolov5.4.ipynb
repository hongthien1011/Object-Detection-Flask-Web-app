# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from ultralytics import YOLO

# %%
model = YOLO(r"D:\runs\detect\zolov5.3_train_mAP-0.979_train3\weights\best.pt")

# %%
model.train(data="D:\Phase3\doorwindow2door-2.v17i.yolov8\data.yaml", epochs=500, batch=-1, patience=0)
# Out:
# Ultralytics YOLOv8.0.167  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %%
torch.cuda.empty_cache()

# %%
model = YOLO("yolov8m.pt")

# %%
model.train(data="D:\Phase3\doorwindow2door-2.v17i.yolov8\data.yaml", epochs=500, batch=-1, patience=0)
# Out:
# Ultralytics YOLOv8.0.167  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %%
torch.cuda.empty_cache()

# %%
model = YOLO("yolov8l.pt")

# %%
model.train(data="D:\Phase3\doorwindow2door-2.v17i.yolov8\data.yaml", epochs=500, batch=-1, patience=0)
# Out:
# Ultralytics YOLOv8.0.167  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %%
torch.cuda.empty_cache()

# %%
model = YOLO("yolov8x.pt")

# %%
model.train(data="D:\Phase3\doorwindow2door-2.v17i.yolov8\data.yaml", epochs=500, batch=-1, patience=0)
# Out:
# New https://pypi.org/project/ultralytics/8.0.168 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.167  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...
