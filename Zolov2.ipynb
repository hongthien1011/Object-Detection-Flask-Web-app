# %%
# import torch
# torch.cuda.is_available()

# %%
from ultralytics import YOLO

# %%
# model = YOLO("yolov8m.yaml")

# %%
model = YOLO(r"D:\runs\detect\zolov2_train\weights\best.pt")

# %%
# model.train(data="D:\Floor_plan.v14i.yolov8\data.yaml", epochs=100, batch=-1)

# %%
# !yolo task=detect mode=val split=test model=D:/runs/detect/zolov2_train/weights/best.pt data=D:\Phase1\Floor_plan.v14i.yolov8\data.yaml
# Out:
# Ultralytics YOLOv8.0.141  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8m summary (fused): 218 layers, 25841497 parameters, 0 gradients
#
# val: Scanning D:\Phase1\Floor_plan.v14i.yolov8\test\labels...:   0%|          | 0/68 [00:00<?, ?it/s]
# val: Scanning D:\Phase1\Floor_plan.v14i.yolov8\test\labels... 2 images, 0 backgrounds, 0 corrupt:   3%|2         | 2/68 [00:00<00:03, 17.22it/s]
# val: Scanning D:\Phase1\Floor_plan.v14i.yolov8\test\labels... 40 images, 0 backgrounds, 0 corrupt:  59%|#####8    | 40/68 [00:00<00:00, 200.26it/s]
# val: Scanning D:\Phase1\Floor_plan.v14i.yolov8\test\labels... 68 images, 0 backgrounds, 0 corrupt: 100%|##########| 68/68 [00:00<00:00, 214.89it/s]
# val: New cache created: D:\Phase1\Floor_plan.v14i.yolov8\test\labels.cache
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/5 [00:00<?, ?it/s]
# ...

# %%
# results = model(['file_13_jpg.rf.48376b6c7dd84dfd4c04b39aed84e0a0.jpg'], save=True,show_labels=False)  # return a generator of Results objects
# Out:
# 0: 640x640 1 2door, 2 doors, 13 windows, 302.3ms
# Speed: 28.4ms preprocess, 302.3ms inference, 15.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict6

# %%
import os
import random
path = r'D:\Phase1\Floor_plan.v14i.yolov8\test2\images'
# arr = os.listdir(path)
# # randomlist = random.sample(range(0, 4999), 10)
# randomlist = len(path)
# test_list = []

# for i in range(0,randomlist):
#     img = arr[i]
#     test_list.append(r'{}\{}'.format(path,img))
# results = model(test_list, save=True,show_labels=False, iou = 0.3)
model.predict(path, save=True, conf=0.25, show=False,show_labels=True)
# Out:
# image 1/54 D:\Phase1\Floor_plan.v14i.yolov8\test2\images\file_0_png.rf.0dbcff4277b17ed812f2a3b8fdeb832a.jpg: 512x640 6 doors, 5 windows, 126.9ms
# image 2/54 D:\Phase1\Floor_plan.v14i.yolov8\test2\images\file_0_png.rf.91a44844c2224db39503408976becd90.jpg: 640x608 6 doors, 4 windows, 113.8ms
# image 3/54 D:\Phase1\Floor_plan.v14i.yolov8\test2\images\file_10_png.rf.f20783698754a11ce971da47351575a2.jpg: 640x608 6 doors, 4 windows, 84.7ms
# image 4/54 D:\Phase1\Floor_plan.v14i.yolov8\test2\images\file_11_png.rf.a63ae2e378fd7f05f1413acf6d1487a6.jpg: 640x608 6 doors, 4 windows, 75.1ms
# image 5/54 D:\Phase1\Floor_plan.v14i.yolov8\test2\images\file_12_png.rf.04b4a0c2f50910f9be5317bafd8f2f85.jpg: 640x608 6 doors, 4 windows, 75.2ms
# image 6/54 D:\Phase1\Floor_plan.v14i.yolov8\test2\images\file_13_png.rf.40c7e52a73e0fb952ff4c1951656f32e.jpg: 640x608 6 doors, 4 windows, 99.7ms
# ...

# %%
# path = model.export(format="onnx")
