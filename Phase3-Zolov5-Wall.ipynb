# %%
from ultralytics import YOLO

# %%
# model = YOLO("yolov8m.pt")

# %%
# model.train(data="D:\Phase3\Floor_plan_wall_only.v14i.yolov8\data.yaml", epochs=300, batch=-1, patience=50, pretrained=True)
# Out:
# New https://pypi.org/project/ultralytics/8.0.162 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.160  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %%
model = YOLO(r"D:\runs\detect\zolowallv5.0_train_mAP50-0.859_train4\weights\best.pt")

# %%
model.train(data="D:\Phase3\Floor_plan_wall_only.v15i.yolov8\data.yaml", epochs=300, batch=-1, patience=50, pretrained=True)
# Out:
# New https://pypi.org/project/ultralytics/8.0.162 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.160  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %%
model = YOLO(r"D:\runs\detect\train\weights\best.pt")

# %%
model.train(data="D:\Phase3\Floor_plan_wall_only.v14i.yolov8\data.yaml", epochs=300, batch=-1, patience=50)
# Out:
# New https://pypi.org/project/ultralytics/8.0.162 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.160  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...
