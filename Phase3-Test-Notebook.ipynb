# %%
# from ultralytics import YOLO
# from ray import tune

# %%
# from tuner import run_ray_tune

# %%
# import wandb
# wandb.login()

# %%
# from ray.tune.tuner import Tuner

# %%
# ray.shutdown()

# %%
# import ray
# ray.init()
# ray.cluster_resources()
# Out:
# 2023-08-24 13:17:05,431	INFO worker.py:1612 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# {'memory': 12700196046.0,
#  'object_store_memory': 6350098022.0,
#  'node:127.0.0.1': 1.0,
#  'CPU': 20.0,
#  'node:__internal_head__': 1.0,
#  'GPU': 1.0}

# %%
# model = YOLO("yolov8m.pt")

# %%
# result = model.tune(data=r"D:\Phase2\Phase2Data-DoorWindow2Door.v5i.yolov8\data.yaml", space={"epochs": tune.choice([2,3,6]),
#                                                 "lr0": tune.uniform(0.001,0.1), 
#                                                 "imgsz":tune.choice([16,32,64])}, max_samples=3, gpu_per_trial=0)

# %%
# experiment_path = r"D:\runs\tune\_tune_2023-08-23_11-29-35"
# print(f"Loading results from {experiment_path}...")

# restored_tuner = tune.Tuner.restore(experiment_path, trainable="_tune")
# result_grid = restored_tuner.get_results()

# %%
# tuner = Tuner(trainable=result_grid, run_config=RunConfig(name="my_tune_run"))

# %%
# if result_grid.errors:
#     print("One or more trials failed!")
# else:
#     print("No errors!")

# %%
# import matplotlib.pyplot as plt

# for result in result_grid:
#     plt.plot(result.metrics_dataframe["training_iteration"], result.metrics_dataframe["mean_accuracy"], label=f"Trial {i}")

# plt.xlabel('Training Iterations')
# plt.ylabel('Mean Accuracy')
# plt.legend()
# plt.show()

# %%
from ultralytics import YOLO

# %%
model = YOLO(r"D:\runs\detect\zolov5.3_train_mAP-0.979_train3\weights\best.pt")

# %%
path = r'D:\Phase3\TestData.original\data.yaml'
metrics = model.val(data=path)
# Out:
# Ultralytics YOLOv8.0.160  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# Model summary (fused): 218 layers, 25844392 parameters, 0 gradients
# val: Scanning D:\Phase3\TestData.original\test\labels... 97 images, 0 backgrounds, 0 corrupt: 100%|██████████| 97/97 [0
# val: New cache created: D:\Phase3\TestData.original\test\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:02<0
#                    all         97       1298      0.853      0.689      0.785       0.48
#                  2door         97        101      0.736      0.752      0.764       0.44
#              baywindow         97          3          1       0.39      0.863      0.612
#                   door         97        658      0.976       0.85      0.919      0.577
#                window1         97         71      0.628      0.535      0.588      0.359
# ...

# %%
path = r'D:\Phase3\TestData.640\data.yaml'
metrics = model.val(data=path)
# Out:
# Ultralytics YOLOv8.0.160  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# val: Scanning D:\Phase3\TestData.640\test\labels... 97 images, 0 backgrounds, 0 corrupt: 100%|██████████| 97/97 [00:00<
# val: New cache created: D:\Phase3\TestData.640\test\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:05<0
#                    all         97       1298      0.868      0.531      0.631      0.379
#                  2door         97        101      0.688      0.703      0.775      0.417
#              baywindow         97          3          1      0.481       0.83      0.588
#                   door         97        658      0.968       0.76      0.877      0.527
#                window1         97         71      0.759      0.465      0.513      0.304
#                window2         97        436      0.874      0.443       0.58      0.304
# ...

# %%
path = r'D:\Phase3\TestData.original\test\images'
model.predict(path, conf=0.25, show_labels=False, iou=0.3, save=True, verbose=False)
# Out:
# Results saved to runs\detect\predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: '2door', 1: 'baywindow', 2: 'door', 3: 'window1', 4: 'window2', 5: 'window4', 6: 'window5', 7: 'window6'}
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
# ...

# %%
path = r'D:\Phase3\TestData.640\test\images'
model.predict(path, conf=0.25, show_labels=False, iou=0.3, save=True, verbose=False)
# Out:
# Results saved to runs\detect\predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: '2door', 1: 'baywindow', 2: 'door', 3: 'window1', 4: 'window2', 5: 'window4', 6: 'window5', 7: 'window6'}
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
# ...

# %%
#Test zolov3

# %%
model = YOLO(r"D:\runs\detect\zolov3_train\weights\best.pt")

# %%
path = r'D:\Phase3\TestData.original\data.yaml'
metrics = model.val(data=path)
# Out:
# Ultralytics YOLOv8.0.160  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# Model summary (fused): 218 layers, 25844392 parameters, 0 gradients
# val: Scanning D:\Phase3\TestData.original\test\labels.cache... 97 images, 0 backgrounds, 0 corrupt: 100%|██████████| 97
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:02<0
#                    all         97       1298      0.835       0.57      0.676      0.388
#                  2door         97        101      0.755      0.604      0.678      0.427
#              baywindow         97          3          1          0       0.39      0.039
#                   door         97        658      0.961      0.851       0.91      0.545
#                window1         97         71      0.613      0.535      0.529       0.31
#                window2         97        436      0.927      0.526      0.641      0.338
# ...

# %%
path = r'D:\Phase3\TestData.640\data.yaml'
metrics = model.val(data=path)
# Out:
# Ultralytics YOLOv8.0.160  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# val: Scanning D:\Phase3\TestData.640\test\labels.cache... 97 images, 0 backgrounds, 0 corrupt: 100%|██████████| 97/97 [
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:05<0
#                    all         97       1298      0.862      0.425      0.522      0.308
#                  2door         97        101      0.927      0.515      0.648      0.393
#              baywindow         97          3          1          0          0          0
#                   door         97        658      0.942      0.768      0.879      0.512
#                window1         97         71      0.673      0.507      0.515      0.288
#                window2         97        436        0.9      0.453      0.604      0.311
#                window4         97         14      0.913      0.214      0.285      0.149
# ...

# %%
path = r'D:\Phase3\TestData.original\test\images'
model.predict(path, conf=0.25, show_labels=False, iou=0.3, save=True, verbose=False)
# Out:
# Results saved to runs\detect\predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: '2door', 1: 'baywindow', 2: 'door', 3: 'window1', 4: 'window2', 5: 'window4', 6: 'window5', 7: 'window6'}
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
# ...

# %%
path = r'D:\Phase3\TestData.640\test\images'
model.predict(path, conf=0.25, show_labels=False, iou=0.3, save=True, verbose=False)
# Out:
# Results saved to runs\detect\predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: '2door', 1: 'baywindow', 2: 'door', 3: 'window1', 4: 'window2', 5: 'window4', 6: 'window5', 7: 'window6'}
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
# ...

# %%
from sahi import AutoDetectionModel
from sahi.utils.cv import read_image
from sahi.utils.file import download_from_url
from sahi.predict import get_prediction, get_sliced_prediction, predict
from IPython.display import Image

# %%
detection_model = AutoDetectionModel.from_pretrained(
    model_type= 'yolov8',
    model_path= r'D:\runs\detect\zolov5.4l_train3\weights\best.pt',
    confidence_threshold=0.75,
    device="cuda:0", # or 'cuda:0'
)

# %%
img_path = r"C:\Users\723040\Downloads\IIa_SL0801.png"

# %%
result = get_prediction(img_path, detection_model)

# %%
result.export_visuals(export_dir="demo_data/",hide_labels= False)

Image("demo_data/prediction_visual.png")

# %%
result = get_sliced_prediction(
    img_path,
    detection_model,
    slice_height = 1080,
    slice_width = 1080,
    overlap_height_ratio = 0.2,
    overlap_width_ratio = 0.2
)
# Out:
# Performing prediction on 12 number of slices.

# %%
result.export_visuals(export_dir="demo_data/",hide_labels= False)

Image("demo_data/prediction_visual.png")

# %%
result.to_coco_annotations()
# Out:
# [{'image_id': None,
#   'bbox': [2346.196533203125,
#    1131.9782104492188,
#    140.0849609375,
#    120.80255126953125],
#   'score': 0.891994297504425,
#   'category_id': 2,
#   'category_name': 'door',
#   'segmentation': [],
#   'iscrowd': 0,
#   'area': 16922},
#  {'image_id': None,
#   'bbox': [1628.084228515625,
#    1121.697509765625,
#    133.675537109375,
#    111.87396240234375],
#   'score': 0.8843637704849243,
#   'category_id': 2,
#   'category_name': 'door',
#   'segmentation': [],
#   'iscrowd': 0,
#   'area': 14954},
#  {'image_id': None,
#   'bbox': [1970.3251953125,
#    1116.5109252929688,
#    141.8271484375,
#    118.51858520507812],
#   'score': 0.845371663570404,
#   'category_id': 2,
#   'category_name': 'door',
#   'segmentation': [],
#   'iscrowd': 0,
#   'area': 16809},
#  {'image_id': None,
#   'bbox': [2361.4315795898438,
#    743.8504638671875,
#    29.333740234375,
#    81.70947265625],
#   'score': 0.7745989561080933,
#   'category_id': 4,
# ...

# %%
result.object_prediction_list
# Out:
# [ObjectPrediction<
#      bbox: BoundingBox: <(2346.196533203125, 1131.9782104492188, 2486.281494140625, 1252.78076171875), w: 140.0849609375, h: 120.80255126953125>,
#      mask: None,
#      score: PredictionScore: <value: 0.891994297504425>,
#      category: Category: <id: 2, name: door>>,
#  ObjectPrediction<
#      bbox: BoundingBox: <(1628.084228515625, 1121.697509765625, 1761.759765625, 1233.5714721679688), w: 133.675537109375, h: 111.87396240234375>,
#      mask: None,
#      score: PredictionScore: <value: 0.8843637704849243>,
#      category: Category: <id: 2, name: door>>,
#  ObjectPrediction<
#      bbox: BoundingBox: <(1970.3251953125, 1116.5109252929688, 2112.15234375, 1235.0295104980469), w: 141.8271484375, h: 118.51858520507812>,
#      mask: None,
#      score: PredictionScore: <value: 0.845371663570404>,
#      category: Category: <id: 2, name: door>>,
#  ObjectPrediction<
# ...

# %%
from sahi.utils.coco import CocoPrediction
def toxyxy(self):
    coco_prediction = CocoPrediction.from_coco_bbox(
                bbox=self.bbox.to_xyxy(),
                category_id=self.category.id,
                category_name=self.category.name,
                score=self.score.value,
                image_id=None,
            )
    return coco_prediction

def to_yolo_annotations(self):
    coco_annotation_list = []
    for object_prediction in self.object_prediction_list:
        coco_annotation_list.append(toxyxy(object_prediction).json)
    return coco_annotation_list

# %%
import pandas as pd
df = pd.DataFrame(to_yolo_annotations(result))

# %%
df[['xmin', 'ymin', 'xmax', 'ymax']] = pd.DataFrame(df['bbox'].tolist())

# %%
df
# Out:
#   image_id                                               bbox     score  \
# 0     None  [2346.196533203125, 1131.9782104492188, 2486.2...  0.891994
# 1     None  [1628.084228515625, 1121.697509765625, 1761.75...  0.884364
# 2     None  [1970.3251953125, 1116.5109252929688, 2112.152...  0.845372
# 3     None  [2361.4315795898438, 743.8504638671875, 2390.7...  0.774599
# 4     None  [2362.6244506835938, 822.4815673828125, 2388.2...  0.768674
#
#    category_id category_name segmentation  iscrowd     area         xmin  \
# 0            2          door           []        0  3114765  2346.196533
# 1            2          door           []        0  2173256  1628.084229
# 2            2          door           []        0  2608570  1970.325195
# 3            4       window2           []        0  1973720  2361.431580
# 4            4       window2           []        0  2159971  2362.624451
#
#           ymin         xmax         ymax
# 0  1131.978210  2486.281494  1252.780762
# ...
