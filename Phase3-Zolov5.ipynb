# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from ultralytics import YOLO

# %%
# model = YOLO("yolov8x.pt")

# %%
# import gc
# torch.cuda.empty_cache()
# gc.collect()

# %%
# model.train(data="D:\Phase3\doorwindow2door-2.v2i.yolov8\data.yaml", epochs=300, batch=-1, patience=50, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.0.158 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.156  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %%
# model = YOLO("yolov8l.pt")

# %%
# model.train(data="D:\Phase3\doorwindow2door-2.v2i.yolov8\data.yaml", epochs=300, batch=-1, patience=50, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.0.158 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.156  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %%
# del model
# with torch.no_grad():
#     torch.cuda.empty_cache()

# %%
# model = YOLO("yolov8m.pt")

# %%
# model.train(data="D:\Phase3\doorwindow2door-2.v2i.yolov8\data.yaml", epochs=300, batch=-1, patience=50, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.0.159 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.156  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %%
# del model
# with torch.no_grad():
#     torch.cuda.empty_cache()

# %%
# model = YOLO("yolov8s.pt")
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 21.5M/21.5M [00:08<00:00, 2.75MB/s]

# %%
# model.train(data="D:\Phase3\doorwindow2door-2.v2i.yolov8\data.yaml", epochs=300, batch=-1, patience=50, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.0.159 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.156  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %%
# model = YOLO(r"D:\runs\detect\Yolov8m\weights\best.pt")

# %%
# model.train(data="D:\Phase2\Phase2Data-DoorWindow2Door.v5i.yolov8\data.yaml", epochs=300, batch=-1, patience=50, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.160  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %%
torch.cuda.empty_cache()

# %%
model = YOLO(r"D:\runs\detect\train2\weights\best.pt")

# %%
model.train(data="D:\Phase3\doorwindow2door-2.v2i.yolov8\data.yaml", epochs=300, batch=-1, patience=0, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.0.161 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.160  Python-3.9.17 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...
